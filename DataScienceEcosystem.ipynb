# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### Introduction
#
# Following are the topics coverd in this course and by this Jupyter Notebook :
# * 1: Overview of Data Science Tools
# * 2: Languages of Data Science
# * 3: Libraries, APIs, Datasets, and Models
# * 4: Jupyter Project
# * 5: Sharinng this file on to GitHub

# %% [markdown]
# ### Data Science Languages
#
# Some of the popular languages in data science are:
#
# * 1. Python
# * 2. R Language
# * 3. SQL
# * 4. Scala
# * 5. Java
# * 6. C++
# * 7. Julia
# * 8. JavaScript
# * 9. PHP
# * 10. Go
# * 11. Ruby

# %% [markdown]
#  ### Data Science Libraries
#
#  Some of the commonly used libraries used by Data Scientists include:
#
#  * 1. dplyr
#  * 2. tensorflow
#  * 3. scikit-learn
#  * 4. seaborn
#  * 5. Numpy
#  * 6. Pands
#  * 7. matplotlib
#  * 8. Pytorch
#  * 9. sciPy

# %% [markdown]
# ### Data Science tools
#
# | Type of tools | open Source tools | Commercial tools|
# | --- | --- | --- |
# | Data management |  MySQL, PostgreSQL, MongoDB, Cassandra | Oracle Database, Microsoft SQL Server, and IBM Db2 |
# | Data integration| Apache AirFlow, KubeFlow, Apache Kafka|Informatica PowerCenter and IBM InfoSphere DataStage|
# | Model deployment| Kubernetes, Redhat OpenShift, Mleap, TensorFlow service| SPSS , SAS|

# %% [markdown]
# ### Arithmetic Expression Examples
#
# Arithmetic expressions are used to perform mathematical calculations and operations. They involve various mathematical operators such as addition, subtraction, multiplication, and division.
#
# * 3+3 = 6
# * 5-3 = 2
# * 4*4 = 16

# %%
### Multiply and Add numbers
### This a simple arithmetic expression to mutiply then add integers
a=3
b=4
print(a+b)
print(a*b)
(3*4)+3
# Out:
# 7
# 12
# 15

# %%
## convert minutes to hours
## This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
print(hours)

# %% [markdown]
# ### Objectives.
#
# * understaing the data science essital tools, languges and Libraries
# * how to use git hub
# * Understanding jupyter notebooks

# %% [markdown]
# ## Author
#
# Priya Madhuri Gattem
